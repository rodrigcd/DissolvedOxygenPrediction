# %% [markdown]
# # Projecto Machine Learning

# %%
import matplotlib.pyplot as plt
import matplotlib; matplotlib.rcParams['figure.figsize'] = (15, 6)
import numpy as np
import GPy
from OX_database import DissolvedOxygenDatabase
from IPython.display import display
#GPy.plotting.change_plotting_library('plotly')

# %% [markdown]
# # Cargar base de datos

# %%
path = "/home/rodrigo/ml_prob/DissolvedOxygenPrediction/database/"
sequence_size = 3
train_prop = 0.75
first_day = [2007, 7, 1]

database = DissolvedOxygenDatabase(database_path=path,
                                   sequence_size=3,
                                   train_prop=train_prop,
                                   sequence_batch_size=50,
                                   start_date=first_day)
# Out:
# loading Dissolved_Oxygen
# loading Temperature
# loading pH
# loading Electrical_Conductivity
# loading River_Discharge

# %%
train_input, train_target, train_days = database.next_batch(batch_size="all")
train_target = train_target[..., np.newaxis]
max_days = float(np.amax(train_days))
train_days = train_days[..., np.newaxis]/max_days
test_input, test_target, test_days = database.next_batch(set="test")
test_target = test_target[..., np.newaxis]
test_days = test_days[..., np.newaxis]/max_days
print(train_target.shape, train_days.shape)
# Out:
# ((1661, 1), (1661, 1))

# %% [markdown]
# ## Relación entre variables

# %%
t_target = train_target[:, 0]
n_points = 20

f, axarr = plt.subplots(1,3)
xedges, yedges = np.linspace(np.amin(train_input[:, 0]), np.amax(train_input[:, 0]), n_points), np.linspace(-2, 2, n_points)
hist, xedges, yedges = np.histogram2d(train_input[:, 0], t_target, (xedges, yedges))
xidx = np.clip(np.digitize(train_input[:, 0], xedges), 0, hist.shape[0]-1)
yidx = np.clip(np.digitize(t_target, yedges), 0, hist.shape[1]-1)
c = hist[xidx, yidx]
sc = axarr[0].scatter(train_input[:, 0], t_target, c=c)
#plt.colorbar(sc, orientation='horizontal')
axarr[0].set_xlabel("pH")
axarr[0].set_ylabel("Dissolved Oxygen")

xedges, yedges = np.linspace(np.amin(train_input[:, 1]), np.amax(train_input[:, 1]), n_points), np.linspace(-2, 2, n_points)
hist, xedges, yedges = np.histogram2d(train_input[:, 1], t_target, (xedges, yedges))
xidx = np.clip(np.digitize(train_input[:, 1], xedges), 0, hist.shape[0]-1)
yidx = np.clip(np.digitize(t_target, yedges), 0, hist.shape[1]-1)
c = hist[xidx, yidx]
sc = axarr[1].scatter(train_input[:, 1], t_target, c=c)
#plt.colorbar(sc, orientation='horizontal')
axarr[1].set_xlabel("Temperature")

xedges, yedges = np.linspace(np.amin(train_input[:, 2]), np.amax(train_input[:, 2]), n_points), np.linspace(-2, 2, n_points)
hist, xedges, yedges = np.histogram2d(train_input[:, 2], t_target, (xedges, yedges))
xidx = np.clip(np.digitize(train_input[:, 2], xedges), 0, hist.shape[0]-1)
yidx = np.clip(np.digitize(t_target, yedges), 0, hist.shape[1]-1)
c = hist[xidx, yidx]
sc = axarr[2].scatter(train_input[:, 2], t_target, c=c)
#plt.colorbar(sc, orientation='horizontal')
axarr[2].set_xlabel("River Discharge")
plt.show()

# %%
t_target = train_target[:, 0]

f, axarr = plt.subplots(1,3)
axarr[0].plot(train_input[:, 0], t_target, 'x')
axarr[0].set_xlabel("pH")
axarr[0].set_ylabel("Dissolved Oxygen")

axarr[1].plot(train_input[:, 1], t_target, 'x')
axarr[1].set_xlabel("Temperature")

axarr[2].plot(train_input[:, 2], t_target, 'x')
axarr[2].set_xlabel("River Discharge")
plt.show()

# %% [markdown]
# ## Kernel exponencial

# %%
kernel = GPy.kern.Exponential(input_dim=1)

# %%
m = GPy.models.GPRegression(train_days, train_target, kernel)

# %%
# +- 2 std 
fig = m.plot()
GPy.plotting.show(fig, filename='exponential_bopt')
#plt.xlim([np.amin(train_days), np.amax(train_target)])
# Out:
#  /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:1743: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.

# %%
m.optimize(messages=True)

# %%
m.optimize_restarts(num_restarts=3)
# Out:
# Optimization restart 1/3, f = -808.70433421
# Optimization restart 2/3, f = -808.704339652
# Optimization restart 3/3, f = -808.704341035
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f9126b8c510>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f9125881b50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f9136bfaa50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f9125881950>]

# %%
display(m)
fig = m.plot()
GPy.plotting.show(fig, filename='exponential_aopt')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -808.704341035<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  Exponential.variance   </td><td class=tg-right>   0.968020092834</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Exponential.lengthscale</td><td class=tg-right>  0.0501840814112</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>3.54364232975e-16</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# ## Periodic Kernel

# %%
periodic_kernel = GPy.kern.PeriodicExponential(input_dim=1, period=0.3)

# %%
periodic_model = GPy.models.GPRegression(train_days, train_target, periodic_kernel)

# %%
# +- 2 std 
fig = periodic_model.plot()
GPy.plotting.show(fig, filename='periodic_before')
#plt.xlim([np.amin(train_days), np.amax(train_target)])

# %%
periodic_model.optimize_restarts(num_restarts=3)
# Out:
# Optimization restart 1/3, f = 450.247547497
# Optimization restart 2/3, f = 536.496971767
# Optimization restart 3/3, f = 559.256202036
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f91255fd6d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f91257538d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f9126a8e050>]

# %%
display(periodic_model)
fig = periodic_model.plot()
GPy.plotting.show(fig, filename='periodic_after')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 450.247547497<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 4<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.                  </b></th><th><b>          value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  periodic_exponential.variance   </td><td class=tg-right>  7666.83721954</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.lengthscale</td><td class=tg-right>  25.9447023823</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.period     </td><td class=tg-right> 0.411280402526</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance         </td><td class=tg-right>0.0946454552543</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
display(periodic_kernel)
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  periodic_exponential.</b></th><th><b>         value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  variance             </td><td class=tg-right> 7666.83721954</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  lengthscale          </td><td class=tg-right> 25.9447023823</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  period               </td><td class=tg-right>0.411280402526</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
def plot_mean_std(x, mean, std, real):
    fig = plt.figure()
    print(x.shape)
    print(mean.shape)
    print(std.shape)
    plt.plot(x, mean, "b", label = "Mean")
    mean = np.reshape(mean, (mean.shape[0],))
    x = np.reshape(x, (x.shape[0],))
    std = np.reshape(std, (std.shape[0],))
    real = np.reshape(real, (std.shape[0],))
    plt.fill_between(x, mean+2*std, mean-2*std, alpha = 0.3)
    plt.plot(x, real, 'x')
    plt.show()

# %%
mu, var = periodic_model.predict(test_days)
plot_mean_std(test_days, mu, var, test_target)
# Out:
# (563, 1)
# (563, 1)
# (563, 1)

# %% [markdown]
# ## Sum of periodic kernels

# %%
def sum_periodic_kernel(n_kernels=5):
    k = GPy.kern.PeriodicExponential(input_dim=1)
    for i in range(n_kernels-1):
        k += GPy.kern.PeriodicExponential(input_dim=1)
    return k

# %%
sum_periodic = sum_periodic_kernel(5)

# %%
display(sum_periodic)
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sum.                              </b></th><th><b>        value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  periodic_exponential.variance     </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.lengthscale  </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.period       </td><td class=tg-right>6.28318530718</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_1.variance   </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_1.lengthscale</td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_1.period     </td><td class=tg-right>6.28318530718</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_2.variance   </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_2.lengthscale</td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_2.period     </td><td class=tg-right>6.28318530718</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_3.variance   </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_3.lengthscale</td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_3.period     </td><td class=tg-right>6.28318530718</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_4.variance   </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_4.lengthscale</td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential_4.period     </td><td class=tg-right>6.28318530718</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
sum_periodic_model = GPy.models.GPRegression(train_days, train_target, sum_periodic)

# %%
# +- 2 std 
fig = sum_periodic_model.plot()
GPy.plotting.show(fig, filename='sum_periodic')
#plt.xlim([np.amin(train_days), np.amax(train_target)])

# %%
sum_periodic_model.optimize_restarts(num_restarts=2)
# Out:
# Optimization restart 1/2, f = 559.256194198
# Optimization restart 2/2, f = 221.672759923
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f91252d94d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f91254eaa10>]

# %%
display(sum_periodic_model)
fig = sum_periodic_model.plot()
GPy.plotting.show(fig, filename='sum_periodic_after')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 221.672759923<br>
# <b>Number of Parameters</b>: 16<br>
# <b>Number of Optimization Parameters</b>: 16<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.                        </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.periodic_exponential.variance     </td><td class=tg-right>    40.6037879965</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential.lengthscale  </td><td class=tg-right>1.01030387456e-17</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential.period       </td><td class=tg-right>    15.3283886405</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_1.variance   </td><td class=tg-right>    60.4587855946</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_1.lengthscale</td><td class=tg-right>   0.199596075599</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_1.period     </td><td class=tg-right>   0.421588415384</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_2.variance   </td><td class=tg-right>   0.816764788998</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_2.lengthscale</td><td class=tg-right> 0.00620008119704</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_2.period     </td><td class=tg-right>   0.580987333626</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_3.variance   </td><td class=tg-right>    78.2478032931</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_3.lengthscale</td><td class=tg-right>    3.32249106649</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_3.period     </td><td class=tg-right>   0.781285261171</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_4.variance   </td><td class=tg-right>    30.8312537652</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_4.lengthscale</td><td class=tg-right>0.000310783899999</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.periodic_exponential_4.period     </td><td class=tg-right>   0.345095501028</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance               </td><td class=tg-right>  0.0665701634364</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
mu, var = sum_periodic_model.predict(test_days)
plot_mean_std(test_days, mu, var, test_target)
# Out:
# (563, 1)
# (563, 1)
# (563, 1)

# %% [markdown]
# ## Locally periodic kernel

# %%
locally_periodic_kernel = GPy.kern.Exponential(input_dim=1) * GPy.kern.PeriodicExponential(input_dim=1)
display(locally_periodic_kernel)
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  mul.                            </b></th><th><b>        value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  Exponential.variance            </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Exponential.lengthscale         </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.variance   </td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.lengthscale</td><td class=tg-right>          1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.period     </td><td class=tg-right>6.28318530718</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
locally_periodic_model = GPy.models.GPRegression(train_days, train_target, locally_periodic_kernel)

# %%
# +- 2 std 
fig = locally_periodic_model.plot()
GPy.plotting.show(fig, filename='locally_periodic_before')
#plt.xlim([np.amin(train_days), np.amax(train_target)])

# %%
locally_periodic_model.optimize_restarts(num_restarts=3)
# Out:
# Optimization restart 1/3, f = -808.69298902
# Optimization restart 2/3, f = -816.098405811
# Optimization restart 3/3, f = -799.616307281
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f912575fcd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f9125460290>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f9125460190>]

# %%
display(locally_periodic_model)
fig = locally_periodic_model.plot()
GPy.plotting.show(fig, filename='locally_periodic_after')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -816.098405811<br>
# <b>Number of Parameters</b>: 6<br>
# <b>Number of Optimization Parameters</b>: 6<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.                      </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  mul.Exponential.variance            </td><td class=tg-right>    4.42935503795</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.Exponential.lengthscale         </td><td class=tg-right>  0.0538951419637</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.periodic_exponential.variance   </td><td class=tg-right>    3.53664556532</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.periodic_exponential.lengthscale</td><td class=tg-right>  0.0259090100711</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  mul.periodic_exponential.period     </td><td class=tg-right>    3.88849018933</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance             </td><td class=tg-right>5.15549768956e-14</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>
