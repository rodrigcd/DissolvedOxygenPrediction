# %%
import matplotlib.pyplot as plt
import matplotlib; matplotlib.rcParams['figure.figsize'] = (15, 6)
import numpy as np
import GPy
from OX_database import DissolvedOxygenDatabase
from IPython.display import display
#GPy.plotting.change_plotting_library('plotly')

# %%
path = "/home/rodrigo/ml_prob/DissolvedOxygenPrediction/database/"
sequence_size = 3
train_prop = 0.75
first_day = [2007, 7, 1]

database = DissolvedOxygenDatabase(database_path=path,
                                   sequence_size=3,
                                   train_prop=train_prop,
                                   sequence_batch_size=50,
                                   start_date=first_day)
# Out:
# loading Dissolved_Oxygen
# loading Temperature
# loading pH
# loading Electrical_Conductivity
# loading River_Discharge

# %%
train_input, train_target, train_days = database.next_batch(batch_size="all")
train_target = train_target[..., np.newaxis]
max_days = float(np.amax(train_days))
train_days = train_days[..., np.newaxis]/max_days
test_input, test_target, test_days = database.next_batch(set="test")
test_target = test_target[..., np.newaxis]
test_days = test_days[..., np.newaxis]/max_days
print(train_target.shape, train_days.shape)
# Out:
# ((1661, 1), (1661, 1))

# %%
kernel = GPy.kern.ExpQuad(input_dim=1)

# %%
m = GPy.models.GPRegression(train_days, train_target, kernel)

# %%
# +- 2 std 
fig = m.plot()
GPy.plotting.show(fig, filename='basic_gp_regression_notebook')
#plt.xlim([np.amin(train_days), np.amax(train_target)])

# %%
m.optimize(messages=True)
# Out:
#  /usr/local/lib/python2.7/dist-packages/GPy/kern/src/stationary.py:537: RuntimeWarning:overflow encountered in square

# %%
m.optimize_restarts(num_restarts=3)
# Out:
# Optimization restart 1/3, f = -440.497992294
# Optimization restart 2/3, f = 2287.06795682
# Optimization restart 3/3, f = -440.497992294
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f2954018110>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f2953f34d10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f2954018250>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f295406e890>]

# %%
display(m)
fig = m.plot()
GPy.plotting.show(fig, filename='basic_gp_regression_notebook_optimized')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: -440.497992294<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>           value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  ExpQuad.variance       </td><td class=tg-right>  0.570308158161</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  ExpQuad.lengthscale    </td><td class=tg-right>0.00193147773126</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.00731667209327</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
periodic_kernel = GPy.kern.PeriodicExponential(input_dim=1, period=0.3)

# %%
periodic_model = GPy.models.GPRegression(train_days, train_target, periodic_kernel)

# %%
# +- 2 std 
fig = periodic_model.plot()
GPy.plotting.show(fig, filename='basic_gp_regression_notebook')
#plt.xlim([np.amin(train_days), np.amax(train_target)])

# %%
periodic_model.optimize_restarts(num_restarts=3)
# Out:
# Optimization restart 1/3, f = 450.247547497
# Optimization restart 2/3, f = 448.322132491
# Optimization restart 3/3, f = 432.479034439
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f2952d0f790>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f2952d840d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f2952de94d0>]

# %%
display(periodic_model)
fig = periodic_model.plot()
GPy.plotting.show(fig, filename='basic_gp_regression_notebook_optimized')
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 432.479034439<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 4<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.                  </b></th><th><b>          value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  periodic_exponential.variance   </td><td class=tg-right>  16.9434742945</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.lengthscale</td><td class=tg-right>0.0279908243593</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  periodic_exponential.period     </td><td class=tg-right>  1.03395794449</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance         </td><td class=tg-right>0.0910714007929</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
display(periodic_kernel)
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  periodic_exponential.</b></th><th><b>          value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  variance             </td><td class=tg-right>  16.9434742945</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  lengthscale          </td><td class=tg-right>0.0279908243593</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  period               </td><td class=tg-right>  1.03395794449</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
def plot_mean_std(x, mean, std, real):
    fig = plt.figure()
    print(x.shape)
    print(mean.shape)
    print(std.shape)
    plt.plot(x, mean, "b", label = "Mean")
    mean = np.reshape(mean, (mean.shape[0],))
    x = np.reshape(x, (x.shape[0],))
    std = np.reshape(std, (std.shape[0],))
    plt.fill_between(x, mean+2*std, mean-2*std, alpha = 0.3)
    plt.show()

# %%
mu, var = periodic_model.predict(test_days)
plot_mean_std(test_days, mu, var)
# Out:
# (563, 1)
# (563, 1)
# (563, 1)
